# %%
def Readfile(test, fileName): #讀檔
    fileName = 'input' +fileName +'.txt'
    with open(fileName,'r') as f : 
         data=f.readlines()
    i = 3 
    num = ''
    
    
    
    while i < len(data) :
        j = 0 
        ch = data[i][j]  
        
        while ch != '\t' :
            num += ch  
            j+=1 
            ch = data[i][j]  
        schoolcode = num
        num = ''
        j+=1
        ch = data[i][j]
        while ch != '\t' :
            num += ch  
            j+=1 
            ch = data[i][j]  
        schoolname = num
        j+=1
        num = ''
        ch = data[i][j]
        while ch != '\t' :
            num += ch  
            j+=1 
            ch = data[i][j]  
        majorcode = num
        j+=1
        num = ''
        ch = data[i][j]
        while ch != '\t' :
            num += ch  
            j+=1 
            ch = data[i][j]  
        majorname = num
        j+=1
        num = ''
        ch = data[i][j]
        while ch != '\t' :
            num += ch  
            j+=1 
            ch = data[i][j]  
        time = num
        j+=1
        num = ''
        ch = data[i][j]
        while ch != '\t' :
            num += ch  
            j+=1 
            ch = data[i][j]  
        level = num
        j+=1
        num = ''
        ch = data[i][j]
        while ch != '\t' :
            num += ch  
            j+=1 
            ch = data[i][j]  
        studentNum = num
        j+=1
        num = ''
        ch = data[i][j]
        while ch != '\t' :
            num += ch  
            j+=1 
            ch = data[i][j]  
        teacherNum = num
        j+=1
        num = ''
        ch = data[i][j]
        while ch != '\t' :
            num += ch  
            j+=1 
            ch = data[i][j]  
        graduated = int(num)
        j+=1
        num = ''
        ch = data[i][j]
        while ch != '\t' :
            num += ch  
            j+=1 
            ch = data[i][j]  
        city = num
        j+=1                   
        num = ''
        ch = data[i][j]
        while ch != '\n' :
            num += ch  
            j+=1 
            ch = data[i][j]  
            if i == len(data)-1 and ch == data[len(data)-1][len(data[len(data)-1])-1] : 
                num += ch
                break
        department = num
        num = ''
        New = node( schoolname, majorname, time, level, studentNum, teacherNum, graduated)
        test.append(New)
        i+=1 
        
        

    return test

# %%
class node: #資料型態
    def __init__(self, schoolname, majorname, time, level, studentNum, teacherNum, graduated):
        self.schoolname =schoolname
        self.majorname =majorname
        self.time =time
        self.level =level
        self.studentNum =studentNum
        self.teacherNum =teacherNum
        self.graduated =graduated
        self.left = None
        self.right = None
    
    def insertG(self, schoolname, majorname, time, level, studentNum, teacherNum, graduated):
        if self.graduated <= graduated :    #如果當前資料大於樹的則往右邊走
            if self.left != None :  #如果右邊小孩有資料則再跑一次遞迴
                self.left.insertG(schoolname, majorname, time, level, studentNum, teacherNum, graduated)
            else :  #右邊小孩沒東西的話，就直接插入
                self.left = node(schoolname, majorname, time, level, studentNum, teacherNum, graduated)
        else :    #如果當前資料小於樹的則往左邊走
            if self.right :
                self.right.insertG(schoolname, majorname, time, level, studentNum, teacherNum, graduated)
            else :
                self.right = node(schoolname, majorname, time, level, studentNum, teacherNum, graduated)
                
    def insertN(self, schoolname, majorname, time, level, studentNum, teacherNum, graduated):
        if self.schoolname <= schoolname :  #如果當前資料大於樹的則往右邊走
            if self.left != None:  #如果右邊小孩有資料則再跑一次遞迴
                self.left.insertN(schoolname, majorname, time, level, studentNum, teacherNum, graduated)
            else :    #右邊小孩沒東西的話，就直接插入
                self.left = node(schoolname, majorname, time, level, studentNum, teacherNum, graduated)
        else :    #如果當前資料小於樹的則往左邊走
            if self.right :
                self.right.insertN(schoolname, majorname, time, level, studentNum, teacherNum, graduated)
            else :
                self.right = node(schoolname, majorname, time, level, studentNum, teacherNum, graduated)

# %%
class Sorting :
    def __init__(self) : 
        self.test = []  #存一開始的資料
        self.grad = None  # grad的樹根
        self.name = None  # name的樹根
        self.temp = []  #temp
        
    def PrintTree(self, test): #印出全部資料
        print("學校名稱\t科系名稱\t日間∕進修別\t等級別\t學生數\t教師數\t上學年度畢業生數")
        i = 0
        while i < len(test) :
            print(test[i].schoolname,'\t',test[i].majorname,'\t',test[i].time,'\t',test[i].level,'\t',test[i].studentNum,'\t',test[i].teacherNum,'\t',test[i].graduated)
            i += 1
    
    def SortGrad( self, temp ) :
        if self.grad != None:  #如果root不是NULL就丟進去insertG做遞迴呼叫插入
            self.grad.insertG(temp.schoolname, temp.majorname, temp.time, temp.level, temp.studentNum, temp.teacherNum, temp.graduated)
        else :  #root是NULL的話則直接插入
            self.grad = node(temp.schoolname, temp.majorname, temp.time, temp.level, temp.studentNum, temp.teacherNum, temp.graduated)
            
    def SortName( self, temp ) :
        if self.name != None :  #如果root不是NULL就丟進去insertN做遞迴呼叫插入
            self.name.insertN(temp.schoolname, temp.majorname, temp.time, temp.level, temp.studentNum, temp.teacherNum, temp.graduated)
        else : #root是NULL的話則直接插入
            self.name = node(temp.schoolname, temp.majorname, temp.time, temp.level, temp.studentNum, temp.teacherNum, temp.graduated)
        
               
            
        
    def Height( self, tree ) :  #用遞迴方式測試樹高
        if tree != None :
            leftHeight = self.Height( tree.left )
            rightHeight = self.Height( tree.right )
            if leftHeight > rightHeight :  #看哪一邊比較高就return他
                return leftHeight + 1   #每次遞迴結束+1樹高
            else :
                return rightHeight + 1
        else :
            return 0

# %%
def CreateNode(List,i) :
    temp = node(List[i].schoolname,List[i].majorname,List[i].time,List[i].level,List[i].studentNum,List[i].teacherNum,List[i].graduated )
    return temp

# %%
import time
def main():
            
    print("**********  Binary Tree Sort  **********")
    print("* 0. Quit                              *") 
    print("* 1. Create Two Binary Search Trees    *") 
    print("****************************************") 
    print("Input a Command(0,1):\n")
    mission= input()
       
    while mission != "0" :
        
        fileName = input("Input a file number (e.g., 601, 602, 603, ... ) :"  )
        
        Sort = Sorting() 
        Sort.test = Readfile(Sort.test,fileName)  #讀檔案的資料
        Sort.PrintTree(Sort.test)   #先印出來，確認是否是對的
        
        
        if mission == "1" :
            i = 0
            
            while i < len(Sort.test) :
                Sort.temp = CreateNode(Sort.test, i)
                Sort.SortGrad(Sort.temp) # sort by graduated student number
                Sort.SortName(Sort.temp) # sort by school name
                i += 1
                
            #計算樹高
            HeightG = Sort.Height(Sort.grad)  
            HeightN = Sort.Height(Sort.name)
            
            print("Tree Height")
            print("{Number of Graduates} =", HeightG)
            print("{School Name} = ", HeightN)
            
            
        elif mission == "0" :
            break
        else :
            print("invalid mission number, please try again") 
    
        print("**********  Binary Tree Sort  **********")
        print("* 0. Quit                              *") 
        print("* 1. Create Two Binary Search Trees    *") 
        print("****************************************") 
        print("Input a Command(0,1):")
        mission= input()

# %%
main()
# Out:
# **********  Binary Tree Sort  **********
# * 0. Quit                              *
# * 1. Create Two Binary Search Trees    *
# ****************************************
# Input a Command(0,1):
#
# 1
# Input a file number (e.g., 601, 602, 603, ... ) :601
# 學校名稱	科系名稱	日間∕進修別	等級別	學生數	教師數	上學年度畢業生數
# 國立清華大學 	 資訊工程學系 	 D 日 	 B 學士 	 565 	 43 	 117
# 國立臺灣大學 	 資訊工程學系 	 D 日 	 B 學士 	 520 	 30 	 104
# 國立交通大學 	 資訊工程學系 	 D 日 	 B 學士 	 788 	 24 	 187
# 國立中央大學 	 資訊工程學系 	 D 日 	 B 學士 	 475 	 28 	 109
# 國立中山大學 	 資訊工程學系 	 D 日 	 B 學士 	 234 	 20 	 44
# 國立中正大學 	 資訊工程學系 	 D 日 	 B 學士 	 385 	 24 	 90
# 國立臺北大學 	 資訊工程學系 	 D 日 	 B 學士 	 200 	 12 	 39
# 國立東華大學 	 資訊工程學系 	 D 日 	 B 學士 	 281 	 19 	 51
# 東海大學 	 資訊工程學系 	 D 日 	 B 學士 	 510 	 19 	 107
# 輔仁大學 	 資訊工程學系 	 D 日 	 B 學士 	 485 	 15 	 118
# 中原大學 	 資訊工程學系 	 D 日 	 B 學士 	 444 	 15 	 73
# 淡江大學 	 資訊工程學系 	 D 日 	 B 學士 	 765 	 28 	 179
# 逢甲大學 	 資訊工程學系 	 D 日 	 B 學士 	 929 	 32 	 170
# 長庚大學 	 資訊工程學系 	 D 日 	 B 學士 	 232 	 18 	 43
# 元智大學 	 資訊工程學系 	 D 日 	 B 學士 	 630 	 23 	 142
# ...
